# %%
import pandas as pd

df = pd.read_csv("test.csv")

# %%
df.head()
# Out:
#            cve_id                                              title  \
# 0   CVE-2025-0168  A vulnerability classified as critical has bee...
# 1  CVE-2025-22214  Landray EIS 2001 through 2006 allows Message/f...
# 2   CVE-2025-0171  A vulnerability, which was classified as criti...
# 3   CVE-2025-0172  A vulnerability has been found in code-project...
# 4   CVE-2025-0173  A vulnerability was found in SourceCodester On...
#
#                                          description  \
# 0  A vulnerability classified as critical has bee...
# 1  Landray EIS 2001 through 2006 allows Message/f...
# 2  A vulnerability, which was classified as criti...
# 3  A vulnerability has been found in code-project...
# 4  A vulnerability was found in SourceCodester On...
#
#                published_date               last_modified remotely_exploit  \
# 0  2025-01-01 14:15:23.590000  2025-02-25 21:26:07.113000              Yes
# 1  2025-01-02 04:15:06.277000  2025-01-02 04:15:06.277000               No
# ...
