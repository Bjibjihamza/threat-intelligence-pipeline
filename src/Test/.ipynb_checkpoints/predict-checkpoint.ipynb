# %%
import os
import re
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('raw_cve_details.csv')
df2 = pd.read_csv('cve_details.csv')

# %%
df1 = df1.drop(['url', 'loaded_at' , "cvss_scores" , "published_date" , "last_modified"], axis=1)
df2 = df2.drop(['url', 'loaded_at' , "cvss_scores" , "published_date" , "last_modified"], axis=1)

# %%
df1.head()
# Out:
#            cve_id                                              title  \
# 0  CVE-2025-11608  code-projects E-Banking System POST Parameter ...
# 1   CVE-1999-0095           Sendmail Command Injection Vulnerability
# 2   CVE-1999-0082  Tenable FTP Server Command Injection Vulnerabi...
# 3   CVE-1999-1471  "BSD Passwd Buffer Overflow Root Privilege Esc...
# 4   CVE-1999-1122   SunOS Restore Privilege Escalation Vulnerability
#
#                                          description remotely_exploit  \
# 0  A security vulnerability has been detected in ...            Yes !
# 1  The following products are affected byCVE-1999...            Yes !
# 2  The following products are affected byCVE-1999...            Yes !
# 3  The following products are affected byCVE-1999...               No
# 4  Vulnerability in restore in SunOS 4.0.3 and ea...               No
#
#               source   category  \
# 0  [email protected]  Injection
# 1  [email protected]        NaN
# 2  [email protected]        NaN
# 3  [email protected]        NaN
# 4  [email protected]        NaN
#
#                                    affected_products
# 0                                                 []
# 1  [{"id": "1", "vendor": "Eric_allman", "product...
# 2  [{"id": "1", "vendor": "Ftp", "product": "ftp"...
# 3   [{"id": "1", "vendor": "Bsd", "product": "bsd"}]
# 4  [{"id": "1", "vendor": "Sun", "product": "suno...

# %%
df2.head()
# Out:
#           cve_id                                              title  \
# 0  CVE-2010-0315  WebKit Chrome CSS Injection Information Disclo...
# 1  CVE-2010-0249  Internet Explorer HTML Object Memory Corruptio...
# 2  CVE-2010-0280  Google SketchUp lib3ds Array Index Error Remot...
# 3  CVE-2010-0316  Google SketchUp Integer Overflow Denial of Ser...
# 4  CVE-2010-0317     Novell Netware Denial of Service Vulnerability
#
#                                          description remotely_exploit  \
# 0  The following products are affected byCVE-2010...              NaN
# 1  Use-after-free vulnerability in Microsoft Inte...              NaN
# 2  The following products are affected byCVE-2010...              NaN
# 3  The following products are affected byCVE-2010...              NaN
# 4  The following products are affected byCVE-2010...              NaN
#
#       source_identifier category  \
# 0         cve@mitre.org      NaN
# 1  secure@microsoft.com      NaN
# 2         cve@mitre.org      NaN
# 3         cve@mitre.org      NaN
# 4         cve@mitre.org      NaN
#
#                                    affected_products
# 0  [{"id": "1", "vendor": "Google", "product": "c...
# 1  [{"id": "1", "vendor": "Microsoft", "product":...
# 2  [{"id": "1", "vendor": "Jan_eric_krprianidis",...
# 3  [{"id": "1", "vendor": "Google", "product": "g...
# 4  [{"id": "1", "vendor": "Novell", "product": "n...

# %%
import pandas as pd

# Assuming df1 and df2 are your DataFrames

# Step 1: Stack the datasets on top of each other
df_stacked = pd.concat([df1, df2], ignore_index=True)

# Step 2: Remove duplicates based on the 'cve_id' column, keeping the first occurrence
df_stacked = df_stacked.drop_duplicates(subset='cve_id', keep='first')

# Step 3: Optionally, reset the index if needed
df_stacked = df_stacked.reset_index(drop=True)

# Step 4: Save the stacked and deduplicated DataFrame to a CSV file
df_stacked.to_csv('stacked_deduplicated_dataset.csv', index=False)

# Optionally, display the first few rows of the final DataFrame
print(df_stacked.head())
# Out:
#            cve_id                                              title  \
# 0  CVE-2025-11608  code-projects E-Banking System POST Parameter ...
# 1   CVE-1999-0095           Sendmail Command Injection Vulnerability
# 2   CVE-1999-0082  Tenable FTP Server Command Injection Vulnerabi...
# 3   CVE-1999-1471  "BSD Passwd Buffer Overflow Root Privilege Esc...
# 4   CVE-1999-1122   SunOS Restore Privilege Escalation Vulnerability
#
#                                          description remotely_exploit  \
# 0  A security vulnerability has been detected in ...            Yes !
# 1  The following products are affected byCVE-1999...            Yes !
# 2  The following products are affected byCVE-1999...            Yes !
# 3  The following products are affected byCVE-1999...               No
# 4  Vulnerability in restore in SunOS 4.0.3 and ea...               No
#
#               source   category  \
# 0  [email protected]  Injection
# 1  [email protected]        NaN
# 2  [email protected]        NaN
# 3  [email protected]        NaN
# 4  [email protected]        NaN
#
#                                    affected_products source_identifier
# 0                                                 []               NaN
# 1  [{"id": "1", "vendor": "Eric_allman", "product...               NaN
# 2  [{"id": "1", "vendor": "Ftp", "product": "ftp"...               NaN
# 3   [{"id": "1", "vendor": "Bsd", "product": "bsd"}]               NaN
# 4  [{"id": "1", "vendor": "Sun", "product": "suno...               NaN

# %%
df3 = pd.read_csv("stacked_deduplicated_dataset.csv", low_memory=False)

# %%
df3.tail()
# Out:
#                 cve_id                                              title  \
# 109236   CVE-2014-5684  Runtastic Running & Fitness SSL Certificate Ve...
# 109237   CVE-2014-5685  Runtastic Heart Rate SSL Man-in-the-Middle Attack
# 109238  CVE-2025-54124  XWiki Platform: Any user with editing rights c...
# 109239  CVE-2025-54125  XWiki Platform: Password and email exposure in...
# 109240  CVE-2025-54571  ModSecurity's Insufficient Return Value Handli...
#
#                                               description remotely_exploit  \
# 109236  The following products are affected byCVE-2014...                f
# 109237  The following products are affected byCVE-2014...                f
# 109238  The following products are affected byCVE-2025...              NaN
# 109239  The following products are affected byCVE-2025...              NaN
# 109240  The following products are affected byCVE-2025...              NaN
#
#        source                category  \
# 109236    NaN                     NaN
# 109237    NaN                     NaN
# 109238    NaN  Information Disclosure
# 109239    NaN  Information Disclosure
# 109240    NaN    Cross-Site Scripting
#
#                                         affected_products  \
# 109236  [{"id": "1", "vendor": "Runtastic", "product":...
# 109237  [{"id": "1", "vendor": "Runtastic", "product":...
# 109238  [{"id": "1", "vendor": "Xwiki", "product": "xw...
# 109239  [{"id": "1", "vendor": "Xwiki", "product": "xw...
# 109240  [{"id": "1", "vendor": "Owasp", "product": "mo...
#
#                      source_identifier
# 109236                   cret@cert.org
# 109237                   cret@cert.org
# 109238  security-advisories@github.com
# 109239  security-advisories@github.com
# 109240  security-advisories@github.com

# %%
#df3 is the dataset with the 'category' column
distinct_categories = df3['category'].dropna().unique()

# Print all unique categories
print(distinct_categories)
# Out:
# ['Injection' 'Race Condition' 'Memory Corruption' 'Authorization'
#  'Misconfiguration' 'Cryptography' 'Cross-Site Request Forgery'
#  'Cross-Site Scripting' 'Information Disclosure' 'Path Traversal'
#  'Authentication' 'Server-Side Request Forgery' 'Denial of Service'
#  'XML External Entity' 'Supply Chain'
#  '[{"score": "7.8", "version": "CVSS 3.1", "severity": "HIGH", "vector": "CVSS:3.1/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H", "exploitability_score": "1.8", "impact_score": "5.9", "source": "[email\xa0protected]"}]'
#  '[]']

# %%
import pandas as pd
import os

# Step 1: Replace NaN values in 'category' with a placeholder (e.g., 'Unknown')
df3['category'] = df3['category'].fillna('Unknown')

# Step 2: Iterate through the unique categories (excluding 'Unknown')
categories = df3['category'].unique()

# Step 3: Create a directory to store the CSV files (optional)
output_dir = 'extracted_titles'
os.makedirs(output_dir, exist_ok=True)

# Step 4: Loop through each category, filter the dataset, and save titles to CSV
for category in categories:
    # Skip 'Unknown' category
    if category == 'Unknown':
        continue
    
    # Ensure category is a string (in case it's a number or NaN after filling)
    category = str(category)
    
    # Filter rows belonging to the current category
    category_df = df3[df3['category'] == category]
    
    # Create a filename from the category (replace spaces with underscores)
    filename = os.path.join(output_dir, f"{category.replace(' ', '_')}.csv")
    
    # Save the titles to the CSV file
    category_df[['cve_id', 'title']].to_csv(filename, index=False)
    print(f"Saved titles for category '{category}' to {filename}")

print("\nDone! Unknown category was skipped.")
# Out:
# Saved titles for category 'Injection' to extracted_titles\Injection.csv
# Saved titles for category 'Race Condition' to extracted_titles\Race_Condition.csv
# Saved titles for category 'Memory Corruption' to extracted_titles\Memory_Corruption.csv
# Saved titles for category 'Authorization' to extracted_titles\Authorization.csv
# Saved titles for category 'Misconfiguration' to extracted_titles\Misconfiguration.csv
# Saved titles for category 'Cryptography' to extracted_titles\Cryptography.csv
# Saved titles for category 'Cross-Site Request Forgery' to extracted_titles\Cross-Site_Request_Forgery.csv
# Saved titles for category 'Cross-Site Scripting' to extracted_titles\Cross-Site_Scripting.csv
# Saved titles for category 'Information Disclosure' to extracted_titles\Information_Disclosure.csv
# Saved titles for category 'Path Traversal' to extracted_titles\Path_Traversal.csv
# Saved titles for category 'Authentication' to extracted_titles\Authentication.csv
# Saved titles for category 'Server-Side Request Forgery' to extracted_titles\Server-Side_Request_Forgery.csv
# Saved titles for category 'Denial of Service' to extracted_titles\Denial_of_Service.csv
# Saved titles for category 'XML External Entity' to extracted_titles\XML_External_Entity.csv
# Saved titles for category 'Supply Chain' to extracted_titles\Supply_Chain.csv
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[315], line 30
#      27     filename = os.path.join(output_dir, f"{category.replace(' ', '_')}.csv")
#      29     # Save the titles to the CSV file
# ---> 30     category_df[['cve_id', 'title']].to_csv(filename, index=False)
#      31     print(f"Saved titles for category '{category}' to {filename}")
#      33 print("\nDone! Unknown category was skipped.")
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'extracted_titles\[{"score":_"7.8",_"version":_"CVSS_3.1",_"severity":_"HIGH",_"vector":_"CVSS:3.1\AV:L\AC:L\PR:N\UI:R\S:U\C:H\I:H'

# %%
# Add a new column called 'predicted_category' filled with 'Unknown'
df3['predicted_category'] = 'Unknown'

print("Column 'predicted_category' added successfully!")
print(df3.head())  # View the first few rows to confirm
# Out:
# Column 'predicted_category' added successfully!
#            cve_id                                              title  \
# 0  CVE-2025-11608  code-projects E-Banking System POST Parameter ...
# 1   CVE-1999-0095           Sendmail Command Injection Vulnerability
# 2   CVE-1999-0082  Tenable FTP Server Command Injection Vulnerabi...
# 3   CVE-1999-1471  "BSD Passwd Buffer Overflow Root Privilege Esc...
# 4   CVE-1999-1122   SunOS Restore Privilege Escalation Vulnerability
#
#                                          description remotely_exploit  \
# 0  A security vulnerability has been detected in ...            Yes !
# 1  The following products are affected byCVE-1999...            Yes !
# 2  The following products are affected byCVE-1999...            Yes !
# 3  The following products are affected byCVE-1999...               No
# 4  Vulnerability in restore in SunOS 4.0.3 and ea...               No
#
#               source   category  \
# 0  [email protected]  Injection
# 1  [email protected]    Unknown
# 2  [email protected]    Unknown
# 3  [email protected]    Unknown
# 4  [email protected]    Unknown
#
#                                    affected_products source_identifier  \
# 0                                                 []               NaN
# 1  [{"id": "1", "vendor": "Eric_allman", "product...               NaN
# 2  [{"id": "1", "vendor": "Ftp", "product": "ftp"...               NaN
# 3   [{"id": "1", "vendor": "Bsd", "product": "bsd"}]               NaN
# 4  [{"id": "1", "vendor": "Sun", "product": "suno...               NaN
#
#   predicted_category
# 0            Unknown
# 1            Unknown
# 2            Unknown
# 3            Unknown
# 4            Unknown

# %%
df3.head()
# Out:
#            cve_id                                              title  \
# 0  CVE-2025-11608  code-projects E-Banking System POST Parameter ...
# 1   CVE-1999-0095           Sendmail Command Injection Vulnerability
# 2   CVE-1999-0082  Tenable FTP Server Command Injection Vulnerabi...
# 3   CVE-1999-1471  "BSD Passwd Buffer Overflow Root Privilege Esc...
# 4   CVE-1999-1122   SunOS Restore Privilege Escalation Vulnerability
#
#                                          description remotely_exploit  \
# 0  A security vulnerability has been detected in ...            Yes !
# 1  The following products are affected byCVE-1999...            Yes !
# 2  The following products are affected byCVE-1999...            Yes !
# 3  The following products are affected byCVE-1999...               No
# 4  Vulnerability in restore in SunOS 4.0.3 and ea...               No
#
#               source   category  \
# 0  [email protected]  Injection
# 1  [email protected]    Unknown
# 2  [email protected]    Unknown
# 3  [email protected]    Unknown
# 4  [email protected]    Unknown
#
#                                    affected_products source_identifier  \
# 0                                                 []               NaN
# 1  [{"id": "1", "vendor": "Eric_allman", "product...               NaN
# 2  [{"id": "1", "vendor": "Ftp", "product": "ftp"...               NaN
# 3   [{"id": "1", "vendor": "Bsd", "product": "bsd"}]               NaN
# 4  [{"id": "1", "vendor": "Sun", "product": "suno...               NaN
#
#   predicted_category
# 0            Unknown
# 1            Unknown
# 2            Unknown
# 3            Unknown
# 4            Unknown

# %%
import re
import math
import pandas as pd
from collections import Counter, defaultdict

# =========================================
# CONFIG
# =========================================
CSV_PATH = "raw_cve_details.csv"
OUT_PATH = "raw_cve_details_with_predicted_category.csv"

ALPHA = 1.0          # Laplace smoothing
MIN_TOKEN_LEN = 2
USE_BIGRAMS = True

STOPWORDS = {
    "the","a","an","and","or","of","to","in","for","on","with","by","via",
    "from","at","as","is","are","be","was","were","this","that","these","those",
    "vulnerability","vulnerabilities","issue","bug","attack","remote","local",
    "privilege","escalation","denial","service","dos","code","execution","rce",
    "information","disclosure","leak","overflow","buffer","command","injection",
    "authentication","bypass","default","config","configuration","file","read",
    "write","arbitrary","sun","sunos","solaris","unix","linux","hp","ibm","sgi",
    "irix","cisco","apache","server","client","kernel"
}

# =========================================
# TOKENIZATION
# =========================================
non_alnum = re.compile(r"[^a-z0-9]+")

def tokenize(text: str):
    text = str(text or "").lower()
    text = non_alnum.sub(" ", text)
    toks = [t for t in text.split() if len(t) >= MIN_TOKEN_LEN and t not in STOPWORDS]
    if USE_BIGRAMS and len(toks) >= 2:
        bigrams = [f"{toks[i]}_{toks[i+1]}" for i in range(len(toks)-1)]
        toks.extend(bigrams)
    return toks

# =========================================
# TRAIN MODEL FROM EXISTING CATEGORY
# =========================================
def train_keyword_model(df: pd.DataFrame):
    labeled = df[df["category"].notna() & (df["category"].astype(str).str.strip() != "")]
    if labeled.empty:
        raise ValueError("⚠️ No labeled rows found in 'category'.")

    cat_doc_counts = Counter()
    cat_token_counts = defaultdict(Counter)
    vocab = Counter()

    for _, row in labeled.iterrows():
        cat = str(row["category"])
        cat_doc_counts[cat] += 1
        tokens = tokenize(row.get("title", ""))
        cat_token_counts[cat].update(tokens)
        vocab.update(tokens)

    total_docs = sum(cat_doc_counts.values())
    priors = {cat: math.log(count / total_docs) for cat, count in cat_doc_counts.items()}
    total_tokens = {cat: sum(cnt.values()) for cat, cnt in cat_token_counts.items()}
    vocab_size = len(vocab)

    return {
        "priors_log": priors,
        "token_counts": cat_token_counts,
        "total_tokens": total_tokens,
        "vocab_size": vocab_size,
        "alpha": ALPHA
    }

# =========================================
# PREDICT FUNCTION
# =========================================
def predict_category(title: str, model) -> str:
    tokens = tokenize(title)
    if not tokens:
        return "Unknown"

    priors_log = model["priors_log"]
    token_counts = model["token_counts"]
    total_tokens = model["total_tokens"]
    V = model["vocab_size"]
    alpha = model["alpha"]

    best_cat, best_score = None, -float("inf")
    for cat in priors_log.keys():
        score = priors_log[cat]
        denom = total_tokens[cat] + alpha * V
        counts = token_counts[cat]
        for tok in tokens:
            score += math.log((counts.get(tok, 0) + alpha) / denom)
        if score > best_score:
            best_score, best_cat = score, cat

    return best_cat if best_cat else "Unknown"

# =========================================
# MAIN PREDICTION CYCLE
# =========================================
def run_prediction_cycle():
    df = pd.read_csv(CSV_PATH)

    # Create the column if missing
    if "Predicted_category" not in df.columns:
        df["Predicted_category"] = ""

    # Train model
    model = train_keyword_model(df)

    # Predict for ALL rows (including empty or NaN Predicted_category)
    df["Predicted_category"] = df["title"].apply(lambda t: predict_category(t, model))

    # If a true category exists, keep it (you can remove this line if you want model overrides)
    has_true_cat = df["category"].notna() & (df["category"].astype(str).str.strip() != "")
    df.loc[has_true_cat, "Predicted_category"] = df.loc[has_true_cat, "category"].astype(str)

    # Replace any remaining NaN/empty with "Unknown"
    df["Predicted_category"] = df["Predicted_category"].fillna("Unknown").replace(r"^\s*$", "Unknown", regex=True)

    # Save final dataset
    df.to_csv(OUT_PATH, index=False)
    print(f"✅ Predictions completed and saved to -> {OUT_PATH}")
    print(df[["title", "category", "Predicted_category"]].head(15))
    return df

# =========================================
# EXECUTE
# =========================================
if __name__ == "__main__":
    run_prediction_cycle()
# Out:
# ✅ Predictions completed and saved to -> raw_cve_details_with_predicted_category.csv
#                                                 title        category  \
# 0   code-projects E-Banking System POST Parameter ...       Injection
# 1            Sendmail Command Injection Vulnerability             NaN
# 2   Tenable FTP Server Command Injection Vulnerabi...             NaN
# 3   "BSD Passwd Buffer Overflow Root Privilege Esc...             NaN
# 4    SunOS Restore Privilege Escalation Vulnerability             NaN
# 5           SunOS rcp Command Execution Vulnerability             NaN
# 6              SunOS Sendmail Sensitive Path Analysis             NaN
# 7   Apache NFS Privilege Escalation File System Vu...             NaN
# 8    FreeBSD libmytinfo Buffer Overflow Vulnerability             NaN
# 9   mptcp: always handle address removal under msk...  Race Condition
# 10  SunView (SunTools) selection_svc Remote File R...             NaN
# 11  NeXT BuildDisk Privilege Escalation Vulnerability             NaN
# 12                          NeXT Privilege Escalation             NaN
# 13          NeXT Restore Script Local Root Escalation             NaN
# 14   OpenVMS Local Privilege Escalation Vulnerability             NaN
#
#         Predicted_category
# 0                Injection
# 1        Memory Corruption
# 2        Memory Corruption
# 3           Authentication
# 4        Memory Corruption
# 5        Memory Corruption
# 6   Information Disclosure
# 7                Injection
# 8                Injection
# 9           Race Condition
# 10        Misconfiguration
# 11       Memory Corruption
# 12       Memory Corruption
# 13           Authorization
# 14       Memory Corruption

# %%
df4 = pd.read_csv("raw_cve_details_with_predicted_category.csv", low_memory = False)

# %%
df4.head(10)
# Out:
#            cve_id                                              title  \
# 0  CVE-2025-11608  code-projects E-Banking System POST Parameter ...
# 1   CVE-1999-0095           Sendmail Command Injection Vulnerability
# 2   CVE-1999-0082  Tenable FTP Server Command Injection Vulnerabi...
# 3   CVE-1999-1471  "BSD Passwd Buffer Overflow Root Privilege Esc...
# 4   CVE-1999-1122   SunOS Restore Privilege Escalation Vulnerability
# 5   CVE-1999-1467          SunOS rcp Command Execution Vulnerability
# 6   CVE-1999-1506             SunOS Sendmail Sensitive Path Analysis
# 7   CVE-1999-0084  Apache NFS Privilege Escalation File System Vu...
# 8   CVE-2000-0388   FreeBSD libmytinfo Buffer Overflow Vulnerability
# 9  CVE-2025-21875  mptcp: always handle address removal under msk...
#
#                                          description  \
# 0  A security vulnerability has been detected in ...
# 1  The following products are affected byCVE-1999...
# 2  The following products are affected byCVE-1999...
# 3  The following products are affected byCVE-1999...
# 4  Vulnerability in restore in SunOS 4.0.3 and ea...
# 5  Vulnerability in rcp on SunOS 4.0.x allows rem...
# 6  Vulnerability in SMI Sendmail 4.0 and earlier,...
# 7  The following products are affected byCVE-1999...
# 8  The following products are affected byCVE-2000...
# 9  In the Linux kernel, the following vulnerabili...
#
#               published_date              last_modified remotely_exploit  \
# 0   Oct. 11, 2025, 5:15 p.m.   Oct. 11, 2025, 5:15 p.m.            Yes !
# 1       Oct. 1, 1988, 4 a.m.   April 3, 2025, 1:03 a.m.            Yes !
# 2      Nov. 11, 1988, 5 a.m.   April 3, 2025, 1:03 a.m.            Yes !
# 3       Jan. 1, 1989, 5 a.m.   April 3, 2025, 1:03 a.m.               No
# 4      July 26, 1989, 4 a.m.   April 3, 2025, 1:03 a.m.               No
# 5      Oct. 26, 1989, 4 a.m.   April 3, 2025, 1:03 a.m.            Yes !
# 6      Jan. 29, 1990, 5 a.m.   April 3, 2025, 1:03 a.m.            Yes !
# 7        May 1, 1990, 4 a.m.   April 3, 2025, 1:03 a.m.               No
# 8        May 9, 1990, 4 a.m.   April 3, 2025, 1:03 a.m.            Yes !
# 9  March 27, 2025, 3:15 p.m.  March 27, 2025, 4:45 p.m.               No
#
#                                  source        category  \
# 0                     [email protected]       Injection
# 1                     [email protected]             NaN
# 2                     [email protected]             NaN
# 3                     [email protected]             NaN
# 4                     [email protected]             NaN
# 5                     [email protected]             NaN
# 6                     [email protected]             NaN
# 7                     [email protected]             NaN
# 8                     [email protected]             NaN
# 9  416baaa9-dc9f-4396-8d5f-8c081fb06d67  Race Condition
#
#                                    affected_products  \
# 0                                                 []
# 1  [{"id": "1", "vendor": "Eric_allman", "product...
# 2  [{"id": "1", "vendor": "Ftp", "product": "ftp"...
# 3   [{"id": "1", "vendor": "Bsd", "product": "bsd"}]
# 4  [{"id": "1", "vendor": "Sun", "product": "suno...
# 5  [{"id": "1", "vendor": "Sun", "product": "suno...
# 6  [{"id": "1", "vendor": "Sun", "product": "suno...
# 7   [{"id": "1", "vendor": "Sun", "product": "nfs"}]
# 8  [{"id": "1", "vendor": "Freebsd", "product": "...
# 9  [{"id": "1", "vendor": "Linux", "product": "li...
#
#                                          cvss_scores  \
# 0  [{"score": "7.5", "version": "CVSS 2.0", "seve...
# 1  [{"score": "10", "version": "CVSS 2.0", "sever...
# 2  [{"score": "10", "version": "CVSS 2.0", "sever...
# 3  [{"score": "7.2", "version": "CVSS 2.0", "seve...
# 4  [{"score": "4.6", "version": "CVSS 2.0", "seve...
# 5  [{"score": "10", "version": "CVSS 2.0", "sever...
# 6  [{"score": "7.5", "version": "CVSS 2.0", "seve...
# 7  [{"score": "7.2", "version": "CVSS 2.0", "seve...
# 8  [{"score": "7.5", "version": "CVSS 2.0", "seve...
# 9                                                 []
#
#                                              url  \
# 0  https://cvefeed.io/vuln/detail/CVE-2025-11608
# 1   https://cvefeed.io/vuln/detail/CVE-1999-0095
# 2   https://cvefeed.io/vuln/detail/CVE-1999-0082
# 3   https://cvefeed.io/vuln/detail/CVE-1999-1471
# 4   https://cvefeed.io/vuln/detail/CVE-1999-1122
# 5   https://cvefeed.io/vuln/detail/CVE-1999-1467
# 6   https://cvefeed.io/vuln/detail/CVE-1999-1506
# 7   https://cvefeed.io/vuln/detail/CVE-1999-0084
# 8   https://cvefeed.io/vuln/detail/CVE-2000-0388
# 9  https://cvefeed.io/vuln/detail/CVE-2025-21875
#
#                        loaded_at      Predicted_category
# 0  2025-10-13 12:00:10.184538+00               Injection
# 1  2025-10-13 12:00:10.184538+00       Memory Corruption
# 2  2025-10-13 12:00:10.184538+00       Memory Corruption
# 3  2025-10-13 12:00:10.184538+00          Authentication
# 4  2025-10-13 12:00:10.184538+00       Memory Corruption
# 5  2025-10-13 12:00:10.184538+00       Memory Corruption
# 6  2025-10-13 12:00:10.184538+00  Information Disclosure
# 7  2025-10-13 12:00:10.184538+00               Injection
# 8  2025-10-13 12:00:10.184538+00               Injection
# 9  2025-10-13 12:00:10.184538+00          Race Condition

# %%
import pandas as pd
from sklearn.metrics import accuracy_score

# Assuming df3 is your DataFrame with 'category' and 'predicted_category'

# 1️⃣  Filter out rows where category is NaN or 'Unknown'
df_eval = df4[df4['category'].notna() & (df4['category'].str.lower() != 'unknown')].copy()

# 2️⃣  Calculate accuracy
accuracy = accuracy_score(df_eval['category'], df_eval['Predicted_category'])

# 3️⃣  Print the result
print(f"✅ Overall Accuracy (excluding 'Unknown' and NaN): {accuracy * 100:.2f}%")
# Out:
# ✅ Overall Accuracy (excluding 'Unknown' and NaN): 100.00%
